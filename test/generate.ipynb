# %%
import jax
import jax.numpy as jnp
from jax import lax
import torch
import numpy as np

# %%
### abs

inp = jnp.array([-1.0, 2.0, -3.0])
out = jnp.abs(inp)
print("JAX abs:", out)
# Out:
# JAX abs: [1. 2. 3.]

# %%
jax.lax.acos(inp)
# Out:
# Array([3.1415925,       nan,       nan], dtype=float32)

# %%
lax.max(inp, inp)
# Out:
# Array([-1.,  2., -3.], dtype=float32)

# %%
x1 = np.random.rand(3, 4).astype(np.float32)

# %%
lax.argmax(x1, axis=0, index_dtype=jnp.int32)
# Out:
# Array([0, 1, 1, 1], dtype=int32)

# %%
torch.argmax(torch.tensor(x1), dim=0, index_type=torch.int32)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 torch.argmax(torch.tensor(x1), dim=0, index_type=torch.int32)
#
# TypeError: argmax() got an unexpected keyword argument 'index_type'

# %%
lax.abs(x=inp)
# Out:
# Array([1., 2., 3.], dtype=float32)

# %%
lax.argmax(operand=x1, axis=0, index_dtype=jnp.int32)
# Out:
# Array([2, 2, 0, 0], dtype=int32)

# %%
lax.approx_max_k(operand=inp, k=2, reduction_dimension=0, recall_target=0.5)
# Out:
# [Array([ 2., -1.], dtype=float32), Array([1, 0], dtype=int32)]

# %%
import inspect


inspect.signature(lax.approx_max_k)
# Out:
# <Signature (operand: jax.Array, k: int, reduction_dimension: int = -1, recall_target: float = 0.95, reduction_input_size_override: int = -1, aggregate_to_topk: bool = True) -> tuple[jax.Array, jax.Array]>

# %%
inspect.signature(torch.topk)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 inspect.signature(torch.topk)
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/inspect.py:3348, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3346 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3347     """Get a signature object for the passed callable."""
# -> 3348     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3349                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/inspect.py:3085, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    3081 @classmethod
#    3082 def from_callable(cls, obj, *,
#    3083                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3084     """Constructs Signature for the given callable object."""
# -> 3085     return _signature_from_callable(obj, sigcls=cls,
#    3086                                     follow_wrapper_chains=follow_wrapped,
#    3087                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/inspect.py:2602, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2597     return _signature_from_function(sigcls, obj,
#    2598                                     skip_bound_arg=skip_bound_arg,
#    2599                                     globals=globals, locals=locals, eval_str=eval_str)
#    2601 if _signature_is_builtin(obj):
# -> 2602     return _signature_from_builtin(sigcls, obj,
#    2603                                    skip_bound_arg=skip_bound_arg)
#    2605 if isinstance(obj, functools.partial):
#    2606     wrapped_sig = _get_signature_of(obj.func)
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/inspect.py:2392, in _signature_from_builtin(cls, func, skip_bound_arg)
#    2390 s = getattr(func, "__text_signature__", None)
#    2391 if not s:
# -> 2392     raise ValueError("no signature found for builtin {!r}".format(func))
#    2394 return _signature_fromstr(cls, func, s, skip_bound_arg)
#
# ValueError: no signature found for builtin <built-in method topk of type object at 0x1105ff6d0>

# %%
file_path = "/Users/haifeng/Program/FUEL-JAX/input/abs/01.npz"

# %%
x = np.random.rand(3, 4).astype(np.float32)
np.savez_compressed(file_path, x=x)

# %%
data = np.load("/Users/haifeng/Program/FUEL-JAX/output/abs/test.npz")

# %%
data
# Out:
# NpzFile '/Users/haifeng/Program/FUEL-JAX/output/abs/test.npz' with keys: out

# %%
data["out"]
# Out:
# array([[0.62513006, 0.6944465 , 0.5826604 , 0.85714823],
#        [0.22155215, 0.16254286, 0.36576876, 0.6015664 ],
#        [0.39712742, 0.23268753, 0.14461608, 0.5430027 ]], dtype=float32)

# %%
data.keys()
# Out:
# KeysView(NpzFile '/Users/haifeng/Program/FUEL-JAX/output/abs/test.npz' with keys: out)

# %%
def get_file(op_name):
    return f"/Users/haifeng/Program/FUEL-JAX/input/{op_name}/test_00.npz"

# %%
x = np.random.randn(16, 256, 128)
np.savez_compressed(get_file("acos"), x=x)
out_1 = jax.lax.acos(x=x)
out_2 = torch.acos(torch.from_numpy(x))

# %%
x_tensor = torch.from_numpy(x)
x_tensor = x_tensor.to(torch.float8_e4m3fn)

torch.asin(x_tensor)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[23], line 5
#       1 x_tensor = torch.from_numpy(x)
#       2 x_tensor = x_tensor.to(torch.float8_e4m3fn)
# ----> 5 torch.asin(x_tensor)
#
# NotImplementedError: "asin_vml_cpu" not implemented for 'Float8_e4m3fn'

# %%
x_Array = jnp.array(x, dtype=jnp.float8_e4m3fn)

# %%
lax.asin(x_Array)
# Out:
# Array([[[-0.5, -0.40625, -0.3125, ..., -0.015625, -0.5, -0.375],
#         [-0.1875, 0.0703125, nan, ..., -0.28125, nan, nan],
#         [-0.0429688, nan, 0.6875, ..., -1.625, nan, 0.0546875],
#         ...,
#         [nan, 0.75, -0.0546875, ..., 0.4375, 0.28125, nan],
#         [-0.03125, -0.34375, 1.625, ..., -1.25, 0.5, 0.0078125],
#         [nan, 1.25, 0.8125, ..., 0.75, -1, 0.375]],
#
#        [[0.101562, 0.171875, nan, ..., -0.375, -0.6875, nan],
#         [0.5, -0.140625, nan, ..., 0.6875, -1, nan],
#         [-0.8125, 0.3125, nan, ..., nan, -0.0351562, -1],
#         ...,
#         [1, nan, 0.375, ..., -0.8125, -0.4375, -0.5],
#         [0.625, -0.75, -0.28125, ..., nan, 0.75, -0.00390625],
#         [nan, 0.28125, 0.15625, ..., -0.5, 0.0078125, -0.0859375]],
#
#        [[1, 1, nan, ..., 0.1875, 1.25, -0.4375],
#         [-0.625, -0.09375, -0.34375, ..., -0.109375, 0.5, nan],
#         [1.625, -0.3125, -0.6875, ..., nan, 0.25, -1.625],
#         ...,
#         [0.8125, nan, -0.25, ..., nan, nan, 0.109375],
#         [0.8125, -0.28125, -0.40625, ..., -0.3125, -0.28125, -0.625],
#         [nan, 0.6875, 0.6875, ..., -0.6875, 0.25, -0.6875]],
#
#        ...,
#
#        [[0.5, -0.75, 0, ..., 0.140625, nan, nan],
#         [0.8125, -0.375, 0.5, ..., -0.5, 1.625, 0.140625],
#         [0.375, -0.6875, nan, ..., nan, 1.625, nan],
#         ...,
#         [-0.3125, 0.8125, -0.625, ..., nan, -0.25, 0.5],
#         [0.28125, 0.5, -0.40625, ..., nan, 0.4375, nan],
#         [0.21875, nan, -0.6875, ..., -1, 0.3125, 0.28125]],
#
#        [[0.34375, 0.28125, 1.625, ..., 0.6875, 0.6875, -0.03125],
#         [nan, nan, nan, ..., -0.625, 0.0390625, nan],
#         [-0, 1, -0.6875, ..., 0.8125, -0.40625, -1.625],
#         ...,
#         [0.5, 0.8125, -0.6875, ..., nan, 1.25, 0.28125],
#         [0.109375, nan, -0.21875, ..., nan, nan, nan],
#         [-0.5, -0.40625, -1, ..., 1.625, -0.1875, -1.625]],
#
#        [[nan, nan, -1.25, ..., -1, 0.0625, nan],
#         [nan, -0.40625, -0.3125, ..., 0.8125, -0.8125, -0.0429688],
#         [nan, 0.171875, 1.625, ..., nan, 0.0390625, -1],
#         ...,
#         [0.4375, 0.625, 0.625, ..., 0.171875, nan, -0.75],
#         [nan, 0.625, -0.4375, ..., -1, -0.34375, 0.3125],
#         [0.28125, -1.625, -0.375, ..., -0.171875, -0.6875, 0.0703125]]],      dtype=float8_e4m3fn)

# %%
torch.acos(x_tensor)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 torch.acos(x_tensor)
#
# NotImplementedError: "acos_vml_cpu" not implemented for 'Float8_e4m3fn'

# %%
torch.add(x_tensor, x_tensor)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 torch.add(x_tensor,x_tensor)
#
# NotImplementedError: "add_stub" not implemented for 'Float8_e4m3fn'

# %%
y = np.random.randn(16, 256, 128)

# %%
np.savez_compressed(get_file("atan2"), x=x, y=y)

# %%
x
# Out:
# array([[[-4.73241283e-01, -4.11359501e-01, -3.11700548e-01, ...,
#          -1.61781858e-02, -4.78956225e-01, -3.69178510e-01],
#         [-1.89940399e-01,  7.25882480e-02,  1.37861612e+00, ...,
#          -2.69413517e-01, -1.11238766e+00, -1.29293983e+00],
#         [-4.13579656e-02, -1.18696461e+00,  6.04095931e-01, ...,
#          -9.82967452e-01, -1.38086993e+00,  5.55792367e-02],
#         ...,
#         [ 1.49510017e+00,  6.78972240e-01, -5.35712809e-02, ...,
#           4.49387700e-01,  2.79040008e-01, -1.76804866e+00],
#         [-2.96271370e-02, -3.31341499e-01,  1.01734186e+00, ...,
#          -9.43385766e-01,  5.12830836e-01,  7.70437141e-03],
#         [ 2.10552794e+00,  9.44846506e-01,  7.23677982e-01, ...,
#           6.94373072e-01, -8.32334313e-01,  3.76059839e-01]],
#
#        [[ 9.85273230e-02,  1.64086263e-01,  1.59509710e+00, ...,
#          -3.60353687e-01, -6.43435083e-01,  1.35267098e+00],
#         [ 5.11439079e-01, -1.42203240e-01, -1.19765086e+00, ...,
#           6.04148442e-01, -7.91803961e-01,  2.30319775e+00],
#         [-7.46513678e-01,  2.97857801e-01, -2.24162146e+00, ...,
#           1.54706858e+00, -3.33282854e-02, -8.84529678e-01],
#         ...,
#         [ 8.99151952e-01,  1.36803034e+00,  3.84209815e-01, ...,
#          -7.35232538e-01, -4.28860854e-01, -4.76457030e-01],
#         [ 5.88745523e-01, -7.12441932e-01, -2.68351667e-01, ...,
#           1.46089622e+00,  6.78093805e-01, -3.81469764e-03],
#         [ 1.97676577e+00,  2.88716999e-01,  1.52965201e-01, ...,
#          -5.20789974e-01,  8.88031787e-03, -8.52740175e-02]],
#
#        [[ 8.38156778e-01,  8.51413988e-01, -2.25594845e+00, ...,
#           1.86957807e-01,  9.30179833e-01, -4.37240761e-01],
#         [-5.76968047e-01, -9.05692866e-02, -3.38797388e-01, ...,
#          -1.11734331e-01,  4.61906589e-01,  1.13231161e+00],
#         [ 1.03043919e+00, -3.26099165e-01, -6.28974630e-01, ...,
#          -1.31311073e+00,  2.45596959e-01, -1.04692678e+00],
#         ...,
#         [ 7.34883582e-01, -1.11515930e+00, -2.44216809e-01, ...,
#           1.23743405e+00,  1.13183056e+00,  1.11874029e-01],
#         [ 7.48773385e-01, -2.69323282e-01, -3.92821675e-01, ...,
#          -3.07944228e-01, -2.65909899e-01, -5.72872677e-01],
#         [ 1.26472850e+00,  6.52369874e-01,  6.23369594e-01, ...,
#          -5.98654469e-01,  2.42455946e-01, -6.50810187e-01]],
#
#        ...,
#
#        [[ 4.57411387e-01, -6.92131836e-01,  2.58154287e-04, ...,
#           1.40726152e-01,  2.28708173e+00, -2.27858704e+00],
#         [ 7.44743768e-01, -3.78976614e-01,  4.68574122e-01, ...,
#          -4.75491705e-01,  1.04249451e+00,  1.39603246e-01],
#         [ 3.77973225e-01, -6.06118099e-01,  1.09880420e+00, ...,
#           1.51433344e+00,  1.05895570e+00,  1.30004532e+00],
#         ...,
#         [-3.02327371e-01,  7.80817257e-01, -5.48187854e-01, ...,
#          -2.35910287e+00, -2.45096860e-01,  5.23143442e-01],
#         [ 2.75490900e-01,  4.86516441e-01, -4.14605165e-01, ...,
#          -1.30444559e+00,  4.50345732e-01, -1.55853812e+00],
#         [ 2.21994829e-01, -3.08163871e+00, -6.43019852e-01, ...,
#          -8.17870571e-01,  3.14113723e-01,  2.94307137e-01]],
#
#        [[ 3.56978189e-01,  2.91727421e-01,  1.03361329e+00, ...,
#           6.45764349e-01,  6.03949882e-01, -3.18948698e-02],
#         [ 1.76716499e+00,  1.69072211e+00, -1.52410160e+00, ...,
#          -5.35738408e-01,  3.97021560e-02, -1.34259228e+00],
#         [-2.51722804e-03,  8.32340440e-01, -6.07693146e-01, ...,
#           7.42056366e-01, -4.15467131e-01, -1.01832344e+00],
#         ...,
#         [ 4.83939014e-01,  7.28543412e-01, -6.13531628e-01, ...,
#           1.35133697e+00,  9.26389866e-01,  2.81958638e-01],
#         [ 1.11190942e-01,  1.41040528e+00, -2.22483298e-01, ...,
#           1.10982712e+00,  1.11023566e+00, -1.94277782e+00],
#         [-4.63631756e-01, -4.08073283e-01, -8.27568789e-01, ...,
#           1.01722222e+00, -1.93647194e-01, -1.01446851e+00]],
#
#        [[-1.32967025e+00, -1.48967649e+00, -9.52590726e-01, ...,
#          -7.82212453e-01,  6.32382077e-02, -1.08165549e+00],
#         [-1.61346134e+00, -4.15880010e-01, -2.98429066e-01, ...,
#           7.21936648e-01, -7.76493381e-01, -4.38859281e-02],
#         [-1.49548619e+00,  1.77671074e-01,  1.01916611e+00, ...,
#           1.31726102e+00,  3.94020265e-02, -8.54166109e-01],
#         ...,
#         [ 4.42296456e-01,  5.92220414e-01,  5.38818854e-01, ...,
#           1.78125205e-01,  1.14165266e+00, -6.73193413e-01],
#         [ 1.42433443e+00,  5.62721970e-01, -4.26571172e-01, ...,
#          -7.98704349e-01, -3.47754413e-01,  3.12949812e-01],
#         [ 2.76525608e-01, -9.98660628e-01, -3.67306350e-01, ...,
#          -1.78289622e-01, -6.06082539e-01,  6.81899987e-02]]],
#       shape=(16, 256, 128))

# %%
torch.rsqrt(x_tensor)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 torch.rsqrt(x_tensor)
#
# NotImplementedError: "rsqrt_cpu" not implemented for 'Float8_e4m3fn'
